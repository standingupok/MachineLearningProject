# %%
import pandas as pd

# %%
df = pd.read_json("csvjson.json");

# %%
df
# Out:
#            id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0      842302         M        17.99         10.38          122.80     1001.0
# 1      842517         M        20.57         17.77          132.90     1326.0
# 2    84300903         M        19.69         21.25          130.00     1203.0
# 3    84348301         M        11.42         20.38           77.58      386.1
# 4    84358402         M        20.29         14.34          135.10     1297.0
# ..        ...       ...          ...           ...             ...        ...
# 564    926424         M        21.56         22.39          142.00     1479.0
# 565    926682         M        20.13         28.25          131.20     1261.0
# 566    926954         M        16.60         28.08          108.30      858.1
# 567    927241         M        20.60         29.33          140.10     1265.0
# 568     92751         B         7.76         24.54           47.92      181.0
#
# ...

# %%
df["diagnosis"] = ''

# %%
df
# Out:
#            id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0      842302                  17.99         10.38          122.80     1001.0
# 1      842517                  20.57         17.77          132.90     1326.0
# 2    84300903                  19.69         21.25          130.00     1203.0
# 3    84348301                  11.42         20.38           77.58      386.1
# 4    84358402                  20.29         14.34          135.10     1297.0
# ..        ...       ...          ...           ...             ...        ...
# 564    926424                  21.56         22.39          142.00     1479.0
# 565    926682                  20.13         28.25          131.20     1261.0
# 566    926954                  16.60         28.08          108.30      858.1
# 567    927241                  20.60         29.33          140.10     1265.0
# 568     92751                   7.76         24.54           47.92      181.0
#
# ...

# %%
df.columns
# Out:
# Index(['id', 'diagnosis', 'radius_mean', 'texture_mean', 'perimeter_mean',
#        'area_mean', 'smoothness_mean', 'compactness_mean', 'concavity_mean',
#        'concave points_mean', 'symmetry_mean', 'fractal_dimension_mean',
#        'radius_se', 'texture_se', 'perimeter_se', 'area_se', 'smoothness_se',
#        'compactness_se', 'concavity_se', 'concave points_se', 'symmetry_se',
#        'fractal_dimension_se', 'radius_worst', 'texture_worst',
#        'perimeter_worst', 'area_worst', 'smoothness_worst',
#        'compactness_worst', 'concavity_worst', 'concave points_worst',
#        'symmetry_worst', 'fractal_dimension_worst', ''],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 569 entries, 0 to 568
# Data columns (total 33 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   id                       569 non-null    int64
#  1   diagnosis                569 non-null    object
#  2   radius_mean              569 non-null    float64
#  3   texture_mean             569 non-null    float64
#  4   perimeter_mean           569 non-null    float64
#  5   area_mean                569 non-null    float64
#  6   smoothness_mean          569 non-null    float64
#  7   compactness_mean         569 non-null    float64
#  8   concavity_mean           569 non-null    float64
#  9   concave points_mean      569 non-null    float64
#  10  symmetry_mean            569 non-null    float64
#  11  fractal_dimension_mean   569 non-null    float64
#  12  radius_se                569 non-null    float64
#  13  texture_se               569 non-null    float64
# ...

# %%
df = df.drop('', axis=1)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 569 entries, 0 to 568
# Data columns (total 32 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   id                       569 non-null    int64
#  1   diagnosis                569 non-null    object
#  2   radius_mean              569 non-null    float64
#  3   texture_mean             569 non-null    float64
#  4   perimeter_mean           569 non-null    float64
#  5   area_mean                569 non-null    float64
#  6   smoothness_mean          569 non-null    float64
#  7   compactness_mean         569 non-null    float64
#  8   concavity_mean           569 non-null    float64
#  9   concave points_mean      569 non-null    float64
#  10  symmetry_mean            569 non-null    float64
#  11  fractal_dimension_mean   569 non-null    float64
#  12  radius_se                569 non-null    float64
#  13  texture_se               569 non-null    float64
# ...

# %%
import joblib

# %%
import numpy as np

# %%
def standardize_data(X_test, mean_X_train, std_X_train):
    
    for i in range(len(std_X_train)):
        if std_X_train[i] == 0:
            std_X_train[i] = 1.0
    
    X_test_scaled = (X_test - mean_X_train) / std_X_train
    
    return X_test_scaled

# %%
def sigmoid(z):
    return 1 / (1 + np.exp(-z))

# %%
def predict(X, theta, threshold=0.5):
    z = np.dot(X, theta)
    h = sigmoid(z)
    
    y_pred = (h >= threshold).astype(int)
    return y_pred

# %%
X_new = df.drop("diagnosis", axis=1)

# %%
X_new = X_new.drop("id", axis=1)

# %%
X_new.head()
# Out:
#    radius_mean  texture_mean  perimeter_mean  area_mean  smoothness_mean  \
# 0        17.99         10.38          122.80     1001.0          0.11840
# 1        20.57         17.77          132.90     1326.0          0.08474
# 2        19.69         21.25          130.00     1203.0          0.10960
# 3        11.42         20.38           77.58      386.1          0.14250
# 4        20.29         14.34          135.10     1297.0          0.10030
#
#    compactness_mean  concavity_mean  concave points_mean  symmetry_mean  \
# 0           0.27760          0.3001              0.14710         0.2419
# 1           0.07864          0.0869              0.07017         0.1812
# 2           0.15990          0.1974              0.12790         0.2069
# 3           0.28390          0.2414              0.10520         0.2597
# 4           0.13280          0.1980              0.10430         0.1809
#
#    fractal_dimension_mean  ...  radius_worst  texture_worst  perimeter_worst  \
# ...

# %%
# Tải các tham số
scaling_and_model = joblib.load('model.joblib')

mean_X_train = scaling_and_model['mean']
std_X_train = scaling_and_model['std']
theta_final = scaling_and_model['theta']

# Chuẩn hóa dữ liệu mới và dự đoán
X_new_scaled = standardize_data(X_new, mean_X_train, std_X_train)

# Thêm theta 0
X_new_scaled = np.hstack((np.ones((X_new_scaled.shape[0], 1)), X_new_scaled))
y_pred_new = predict(X_new_scaled, theta_final)

# %%
# y_pred_new

# %%
df["diagnosis"] = y_pred_new

# %%
df
# Out:
#            id  diagnosis  radius_mean  texture_mean  perimeter_mean  \
# 0      842302          1        17.99         10.38          122.80
# 1      842517          1        20.57         17.77          132.90
# 2    84300903          1        19.69         21.25          130.00
# 3    84348301          1        11.42         20.38           77.58
# 4    84358402          1        20.29         14.34          135.10
# ..        ...        ...          ...           ...             ...
# 564    926424          1        21.56         22.39          142.00
# 565    926682          1        20.13         28.25          131.20
# 566    926954          1        16.60         28.08          108.30
# 567    927241          1        20.60         29.33          140.10
# 568     92751          0         7.76         24.54           47.92
#
#      area_mean  smoothness_mean  compactness_mean  concavity_mean  \
# 0       1001.0          0.11840           0.27760         0.30010
# ...

# %%
def train_test_split(X, test_size=0.2, random_state=None):
    np.random.seed(random_state)
    data_size = X.shape[0]
    indices = np.random.permutation(data_size)
    test_set_size = int(test_size * data_size)
    
    test_indices = indices[:test_set_size]
    train_indices = indices[test_set_size:]
    
    X_train, X_test = X.iloc[train_indices], X.iloc[test_indices]
    
    return X_train, X_test

# %%
import pandas as pd
data = pd.read_csv('data.csv')

# %%
data_train, data_test = train_test_split(data, random_state=None)

# %%
import numpy as np

# %%
data_test.to_csv("data_test.csv")

# %%
data_test["diagnosis"] = ''

# %%
data_test = data_test.drop("Unnamed: 32", axis=1)

# %%
data_test.columns
# Out:
# Index(['id', 'diagnosis', 'radius_mean', 'texture_mean', 'perimeter_mean',
#        'area_mean', 'smoothness_mean', 'compactness_mean', 'concavity_mean',
#        'concave points_mean', 'symmetry_mean', 'fractal_dimension_mean',
#        'radius_se', 'texture_se', 'perimeter_se', 'area_se', 'smoothness_se',
#        'compactness_se', 'concavity_se', 'concave points_se', 'symmetry_se',
#        'fractal_dimension_se', 'radius_worst', 'texture_worst',
#        'perimeter_worst', 'area_worst', 'smoothness_worst',
#        'compactness_worst', 'concavity_worst', 'concave points_worst',
#        'symmetry_worst', 'fractal_dimension_worst'],
#       dtype='object')

# %%
data_test = data_test.iloc[:, 1:]

# %%
data_test = data_test.drop(columns=data_test.columns[0], axis=1,  inplace=True)

# %%
data_test
# Out:
#            id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 162    871201                 19.590         18.15          130.70     1214.0
# 409    905501                 12.270         17.92           78.41      466.1
# 50     857343                 11.760         21.60           74.72      427.9
# 21    8510824                  9.504         12.44           60.34      273.9
# 146    869691                 11.800         16.58           78.99      432.0
# ..        ...       ...          ...           ...             ...        ...
# 43     856106                 13.280         20.28           87.32      545.2
# 430    907914                 14.900         22.53          102.10      685.0
# 416    905978                  9.405         21.70           59.60      271.2
# 293    891703                 11.850         17.46           75.54      432.7
# 7    84458202                 13.710         20.83           90.20      577.9
#
# ...

# %%
output_csv_file = "data_test.csv"
data_test.to_csv(output_csv_file, index=False)  # index=False để không ghi cột index vào file CSV
print(f"DataFrame đã được lưu vào file CSV: {output_csv_file}")
# Out:
# DataFrame đã được lưu vào file CSV: data_test.csv

# %%
output_json_file = "data_test.json"
data_test.to_json(output_json_file, orient="records", index=False)  # index=False tự động bỏ qua index
print(f"DataFrame đã được lưu vào file JSON: {output_json_file}")
# Out:
# DataFrame đã được lưu vào file JSON: data_test.json
